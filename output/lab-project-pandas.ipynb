# %% [markdown]
# # Hipotesis
# ### Los ataques de tiburon son mayor causa de muerte en hombres que en mujeres
# Por comodidad, voy a trabajar en una horquilla temporal entre 1900 y los datos más actuales, debido a que con datos anteriores a dicha fecha los datos comienzan a ser ambiguos

# %%
import pandas as pd
import numpy as np
import re
import matplotlib

# %% [markdown]
# ##### Importo el documento de donde vamos a extraer la información:

# %%
df = pd.read_csv("/Users/marilomolinacandela/ironhack/my_repo/input/GSAF5.csv")
pd.set_option('display.max_columns', 30)

display(df.head())

# %% [markdown]
# ##### Observo las columnas para determinar cuales de ellas pueden ser de mayor utilidad a la hora de encontrar respuesta a mi hipotesis

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# ##### Tomo una selección previa de las columnas que creo que me aportarán la información adecuada:

# %%
col = ["Name", "Sex ", "Age", "Case Number", "Country", "Activity", "Species ", "Fatal (Y/N)"]
df_col = df[col]

# %% [markdown]
# ##### Introduzco el límite temporal del que he hablado al comienzo (de 1900 a la actualidad):

# %%
year1900 = (df.Year >= 1900)
df_1900 = df_col[year1900]

# %% [markdown]
# ##### A continuación, renombro algunas columnas con las que voy a trabajar por comodidad:

# %%
rename = {
    'Sex ' :'Sex',
    'Fatal (Y/N)': 'Fatal attack',
    'Species ': 'Shark info',
    'Case Number':'Day'
}

df_rename = df_1900.rename(columns = rename)

# %% [markdown]
# ##### Una vez renombradas las columnas, compruebo si estas contienen valores nulos...

# %%
numnull = df_rename.isnull().sum()[df_rename.isnull().sum() > 0]
numnull
# Out:
# Name             158
# Sex              505
# Age             2103
# Country           22
# Activity         426
# Shark info      2389
# Fatal attack       9
# dtype: int64

# %%
notnull = df_rename.isnull().sum()[df_rename.isnull().sum() == 0]
notnull
# Out:
# Day    0
# dtype: int64

# %% [markdown]
# ##### ...y sustituyo los valores nulos que haya encontrado en cada columna por una etiqueta que advierta sobre la falta de datos:

# %%
# Sustituir valores nulos:

valores = {
    "Name":"Unknown name",
    "Sex":"Unidentified sex",
    "Age":"Unknown age",
    "Country":"Undetermined place",
    "Activity":"Undetermined activity",
    "Shark info":"Undetermined shark",
    "Fatal attack": "Unknown state"
}

df_rename.fillna(value = valores, inplace = True)

# %% [markdown]
# ## LIMPIEZA DE DATOS

# %% [markdown]
# ##### Tras ojear los datos, he encontrado un patrón que ocurre por igual en muchas de las columnas: mucha de la información viene acompañada de espacios, los cuales procedo a eliminar iterando en todas las columnas no numéricas:

# %%
for col in df_rename:
    df_rename[col] = df_rename[col].str.strip()

# %% [markdown]
# ## COLUMNA NAME

# %% [markdown]
# #### Un patrón muy visto en la columna de Name es el uso de 'male' o 'female' cuando no se tiene la información del nombre real. Aunque no es el único patrón, si que es el que más casos contiene.
#
#  -> Para limpiar el contenido, reemplazo 'male' y 'female' (junto a otro grupo de nombres que no hacen referencia al nombre real de la persona) por 'Unknown name'.
#
#  -> Pudiendo utilizar .startswtih("male" o "female") finalmente me he decantado por  .replace para no repetir la misma función tantas veces como cambios quiera gestionar.

# %%
df_rename["Name"].replace({
    'male':'Unknown name', 
    'female':'Unknown name',
    'boy':'Unknown name',
    '2 males':'Unknown name',
    'girl':'Unknown name',
    'boat':'Unknown name',
    'Anonymous':'Unknown name',
    'child':'Unknown name',
    'Unidentified':'Unknown name',
    'a sailor':'Unknown name',
    '2 fishermen':'Unknown name',
    'black male':'Unknown name',
    'Unknown':'Unknown name',
    'sailor':'Unknown name',
    'Occupant: Ben Stratton':'Unknown name',
    'a native':'Unknown name'
}, inplace = True)

display(df_rename.Name.value_counts().head())

name = list(df_rename["Name"])

data_name = pd.DataFrame(name, columns = ["Name"])
data_name
# Out:
# Unknown name    730
# dinghy            3
# M.C.              3
# fisherman         3
# a soldier         3
# Name: Name, dtype: int64
#                                                    Name
# 0                                          Unknown name
# 1                                        Chucky Luciano
# 2                                          Unknown name
# 3                                       Rory Angiolella
# 4                                          Unknown name
# ...                                                 ...
# 5319               Emil Uhlbrecht & unidentified person
# 5320  skiff with Dr. William T. Healey, Dr. Henry Ca...
# 5321                                       Charles Duck
# 5322                                     Emil A. Berndt
# 5323                                         Mr. Gruner
#
# [5324 rows x 1 columns]

# %% [markdown]
# ## COLUMNA SEX:

# %% [markdown]
# #### He usado nuevamente .replace para modificar contenido confuso y para mejorar la legibilidad del dataframe final:
#
# -> He modificado la 'M' por 'Male' y la 'F' por 'Female'.
#
# -> He sustituido 'N', '.' y 'lli' por 'Unidentified sex'.

# %%
df_rename["Sex"].replace({
    'N':'Unidentified sex', 
    '.':'Unidentified sex',
    'lli':'Unidentified sex'
}, inplace = True)

df_rename["Sex"].value_counts()
# Out:
# M                   4268
# F                    548
# Unidentified sex     508
# Name: Sex, dtype: int64

# %%
df_rename["Sex"].replace({
    'M':'Male', 
    'F':'Female'
}, inplace = True)

display(df_rename["Sex"].value_counts())

sex = list(df_rename["Sex"])

data_sex = pd.DataFrame(sex, columns = ["Sex"])
data_sex
# Out:
# Male                4268
# Female               548
# Unidentified sex     508
# Name: Sex, dtype: int64
#                    Sex
# 0                 Male
# 1                 Male
# 2                 Male
# 3                 Male
# 4                 Male
# ...                ...
# 5319              Male
# 5320  Unidentified sex
# 5321              Male
# 5322              Male
# 5323              Male
#
# [5324 rows x 1 columns]

# %% [markdown]
# ## COLUMNA AGE:

# %% [markdown]
# ##### Para la edad he utilizado regex:
# -> re.search me ha ayudado a  encontrar coincidencias en el contenido de la columna con todas aquellas cifras de dos dígitos, o todas aquellas edades desconocidas con la etiqueta 'Unknown age'
#
# -> Para el resto de contenido que no se guiaba por esos patrones, los he agregado como el dígito 0 que más adelante he modificado como 'Unknown age'

# %%
l_age = list(df_rename["Age"])

age = [] 

for e in l_age:
    if re.search(r'\d{1,2}', e):
        age.append(e)
    elif re.search(r'\bUnknown age\b', e):
        age.append(e)
    else:
        age.append(0)

display(df_rename.Age.value_counts().head())        

data_age = pd.DataFrame(age, columns = ["Age"])
data_age
# Out:
# Unknown age    2103
# 17              143
# 18              139
# 20              133
# 19              132
# Name: Age, dtype: int64
#               Age
# 0              16
# 1              36
# 2              43
# 3     Unknown age
# 4     Unknown age
# ...           ...
# 5319  Unknown age
# 5320  Unknown age
# 5321  Unknown age
# 5322  Unknown age
# 5323  Unknown age
#
# [5324 rows x 1 columns]

# %% [markdown]
# ## COLUMNA MONTHS:

# %% [markdown]
# #### La columna Months muestra unicamente el mes en el que ocurrio se registraron los datos, ya que el día no me aporta valor para la investigació y el año puedo conseguirlo mediante la columna year.
#
# Al igual que en la columna anterior, he utidizado regex para poder limpiar de manera efectiva los datos de dicha columna:
#
# -> He convertido en un alista la columna y a continuación he usado un .join para crear una string con todos los datos.
#
# -> El siguiente paso ha sido utilizar .finall para crear una lista con los datos que contaran con el patrón utilizado.
#
# -> Por último, he modificado con .replace el numero extraido por el nombre del mes que le pertenece.

# %%
day = list(df_rename["Day"])

days = ' '.join(day)

all_days = re.findall(r'\b\.\d{2}\.\b', days)

months = [day.strip(".") for day in all_days]
# Out:
#      Date
# 0      09
# 1      09
# 2      09
# 3      09
# 4      09
# ...   ...
# 5318   07
# 5319   07
# 5320   01
# 5321   00
# 5322   00
#
# [5323 rows x 1 columns]

# %%
data_months = pd.DataFrame(months, columns = ["Months"])

data_months.replace({
    '00':'UNKNOWN',
    '01':'January',
    '02':'February',
    '03':'March',
    '04':'April',
    '05':'May',
    '06':'June',
    '07':'July',
    '08':'August',
    '09':'September',
    '10':'October',
    '11':'November',
    '12':'December'
}, inplace = True)

data_months
# Out:
#          Months
# 0     September
# 1     September
# 2     September
# 3     September
# 4     September
# ...         ...
# 5318       July
# 5319       July
# 5320    January
# 5321    UNKNOWN
# 5322    UNKNOWN
#
# [5323 rows x 1 columns]

# %% [markdown]
# ## COLUMNA COUNTRY:

# %% [markdown]
# ##### En la columna de Country a bastado con:
#
# -> Sustituir los valores nulos por 'Undetermined place'.
#
# -> Limpiar los espacios en blanco.

# %%
df_rename.Country.value_counts().head()
country = list(df_rename["Country"])


data_country = pd.DataFrame(country, columns = ["Country"])
data_country
# Out:
#            Country
# 0              USA
# 1              USA
# 2              USA
# 3        AUSTRALIA
# 4        AUSTRALIA
# ...            ...
# 5319           USA
# 5320           USA
# 5321     AUSTRALIA
# 5322           USA
# 5323  SOUTH AFRICA
#
# [5324 rows x 1 columns]

# %% [markdown]
# ## COLUMNA ACTIVITY:

# %% [markdown]
# ##### En la columna Activity he sustituido los valores nulos por 'Undetermined activity'

# %%
df_rename.Activity.value_counts().head()

activity = list(df_rename["Activity"])

data_activity = pd.DataFrame(activity, columns = ["Activity"])
data_activity
# Out:
#                          Activity
# 0                         Surfing
# 1                         Surfing
# 2                         Surfing
# 3                         Surfing
# 4                         Surfing
# ...                           ...
# 5319            Hunting seashells
# 5320
# 5321  Standing, gathering oysters
# 5322        Undetermined activity
# 5323                     Swimming
#
# [5324 rows x 1 columns]

# %% [markdown]
# ## COLUMNA SHARK INFO:

# %% [markdown]
# ##### Al igual que en la columna anterior, en Shark info he limpiado posibles espacios y sustituido los valores nulos por 'Undetermined shark'.

# %%
# SHARK INFO:
# -> Limpiar por especie.
# -> Limpiar pasando de pulgadas a metros.
# NaN == 'Undetermined shark'

df_rename["Shark info"].value_counts().head()
shark = list(df_rename["Shark info"])

data_shark = pd.DataFrame(shark, columns = ["Shark info"])
data_shark
# Out:
#               Shark info
# 0     Undetermined shark
# 1     Undetermined shark
# 2     Undetermined shark
# 3     Undetermined shark
# 4              2 m shark
# ...                  ...
# 5319  Undetermined shark
# 5320  Undetermined shark
# 5321  Undetermined shark
# 5322  Undetermined shark
# 5323  Undetermined shark
#
# [5324 rows x 1 columns]

# %% [markdown]
# ## COLUMNA FATAL ATTACK:

# %% [markdown]
# ##### En los datos de esta columna he realizado varias limpiezas:
#
# -> He usado .replace para la modificación de nombres como 'UNKNOWN' a 'Unknown state' o 'Y' y 'F' como 'Fatal attack' con el objetivo de unificar los datos y mejorar la legibilidad de los mismos.

# %%
df_rename["Fatal attack"].replace({
    'N':'Not fatal attack', 
    'Y':'Fatal attack', 
    'UNKNOWN':'Unknown state', 
    'F':'Fatal attack'
}, inplace = True)

df_rename["Fatal attack"].value_counts()
fatal = list(df_rename["Fatal attack"])

data_fatal = pd.DataFrame(fatal, columns = ["Fatal attack"])
data_fatal
# Out:
#           Fatal attack
# 0     Not fatal attack
# 1     Not fatal attack
# 2     Not fatal attack
# 3     Not fatal attack
# 4     Not fatal attack
# ...                ...
# 5319      Fatal attack
# 5320  Not fatal attack
# 5321  Not fatal attack
# 5322  Not fatal attack
# 5323  Not fatal attack
#
# [5324 rows x 1 columns]

# %% [markdown]
# ## DATAFRAME DEFINITIVO:

# %% [markdown]
# ##### Una vez terminada la limpieza de datos de las columnas que me van a ayudar a resolver mi hipótesis, he unificado dichos datos en un único dataframe

# %%
final_data = df_rename[["Name", "Sex", "Age", "Day", "Country", "Activity", "Shark info", "Fatal attack"]]

df_rename["Name"] = data_name
df_rename["Sex"] = data_sex
df_rename["Age"] = data_age
df_rename["Day"] = data_months
df_rename["Country"] = data_country
df_rename["Activity"] = data_activity
df_rename["Shark info"] = data_shark
df_rename["Fatal attack"] = data_fatal

final_data.head(50)
# Out:
#                                         Name               Sex          Age  \
# 0                               Unknown name              Male           16
# 1                             Chucky Luciano              Male           36
# 2                               Unknown name              Male           43
# 3                            Rory Angiolella              Male  Unknown age
# 4                               Unknown name              Male  Unknown age
# 5                               Unknown name  Unidentified sex  Unknown age
# 6                               Unknown name              Male          60s
# 7                               Unknown name            Female           51
# 8                               David Jewell              Male           50
# 9                             Rylie Williams            Female           12
# 10                             Fraser Penman              Male  Unknown age
# 11                              Austin Moore              Male            9
# 12                           Tyler McQuillen              Male           22
# 13                              Sam Cumiskey              Male           25
# 14                              Unknown name              Male           37
# 15                          Laurent Chardard              Male           20
# 16                            David Cassetty              Male           49
# 17                              Johnny Stoch              Male           15
# 18                             Connor Baxter              Male           21
# 19                               Nolan Tyler              Male           22
# 20                              Unknown name              Male           40
# 21                              Justus Franz              Male           72
# 22                               Ian Watkins              Male  Unknown age
# 23                               Warren Sapp              Male           43
# 24                   Curran See & Harry Lake              Male           18
# 25                              Unknown name              Male           29
# 26                         Zebulon Critchlow              Male           36
# 27                            Steve Cutbirth              Male  Unknown age
# 28                           Scott van Burck              Male           31
# 29                      Occupant: Ben Raines  Unidentified sex  Unknown age
# 30                              Unknown name            Female            9
# 31                              Unknown name            Female           11
# 32                              Unknown name              Male  Unknown age
# 33                         Michael Dornellas              Male  Unknown age
# 34                              Unknown name            Female           10
# 35                                Mark Davis              Male  Unknown age
# 36                             Roger Brissom              Male           59
# 37  24' boat Shark Tagger Occupant Keith Poe              Male  Unknown age
# 38                              Unknown name            Female           42
# 39                             Nathan Oliver              Male           34
# 40                              Unknown name              Male           35
# 41                              Unknown name              Male           11
# 42                              Arturo Velez              Male           59
# 43                              Unknown name              Male           43
# 44                               Jeff Schott              Male           42
# 45                              Unknown name              Male  Unknown age
# 46                              Unknown name              Male  Unknown age
# 47                                 Brad Vale              Male           19
# 48                        Marin Alice Melton            Female            6
# 49                              Dillon Bowen              Male           19
#
#           Day        Country                               Activity  \
# 0   September            USA                                Surfing
# 1   September            USA                                Surfing
# 2   September            USA                                Surfing
# 3   September      AUSTRALIA                                Surfing
# 4   September      AUSTRALIA                                Surfing
# 5   September      AUSTRALIA                                Fishing
# 6   September            USA                                 Wading
# 7   September            USA                               Swimming
# 8   September  NEW CALEDONIA                           Kite surfing
# 9   September            USA                        Boogie boarding
# 10  September      AUSTRALIA                                Surfing
# 11  September            USA                          Body boarding
# 12  September            USA                           Spearfishing
# 13     August            USA                                Surfing
# 14     August            USA                                Surfing
# 15     August        REUNION                                Surfing
# 16     August            USA                                 Wading
# 17     August        BAHAMAS                             Snorkeling
# 18     August            USA                      SUP Foil boarding
# 19     August            USA                                Surfing
# 20       July          SPAIN                               Swimming
# 21       July          CHINA                               Swimming
# 22       July      AUSTRALIA                               Kayaking
# 23       July            USA                             Lobstering
# 24       July      AUSTRALIA                                Surfing
# 25       July          JAPAN                                Surfing
# 26       July      AUSTRALIA                                Surfing
# 27       July        BAHAMAS                           Spearfishing
# 28       July      AUSTRALIA                                Fishing
# 29       July            USA  Fishing in Alabama Deep Fishing Rodeo
# 30       July            USA                                Surfing
# 31       July            USA                  Undetermined activity
# 32       July            USA                               Swimming
# 33       July        BAHAMAS                           Scuba Diving
# 34       July          SPAIN                                 Wading
# 35       July            USA                      Fishing for squid
# 36       July            USA                                Fishing
# 37       July            USA                     Fishing for sharks
# 38       July            USA                               Swimming
# 39       July      AUSTRALIA                                Fishing
# 40       June            USA                  Undetermined activity
# 41       June            USA                                Surfing
# 42       June       COLUMBIA                           Scuba Diving
# 43       June   SOUTH AFRICA                           Spearfishing
# 44       June            USA                               Floating
# 45       June            USA                                 Wading
# 46       June            USA                                Surfing
# 47       June      AUSTRALIA                           Spearfishing
# 48       June            USA                       Floating in tube
# 49       June            USA                               Standing
#
#                     Shark info      Fatal attack
# 0           Undetermined shark  Not fatal attack
# 1           Undetermined shark  Not fatal attack
# 2           Undetermined shark  Not fatal attack
# 3           Undetermined shark  Not fatal attack
# 4                    2 m shark  Not fatal attack
# 5           Undetermined shark  Not fatal attack
# 6               3' to 4' shark  Not fatal attack
# 7             Tiger shark, 10?  Not fatal attack
# 8           Undetermined shark      Fatal attack
# 9           Undetermined shark  Not fatal attack
# 10          Undetermined shark  Not fatal attack
# 11          Undetermined shark  Not fatal attack
# 12                 White shark  Not fatal attack
# 13              Bull shark, 6'  Not fatal attack
# 14          Undetermined shark  Not fatal attack
# 15           Bull shark, 3.5 m  Not fatal attack
# 16          Undetermined shark  Not fatal attack
# 17          Undetermined shark  Not fatal attack
# 18            Tiger shark, 10'  Not fatal attack
# 19              Blacktip shark  Not fatal attack
# 20                  Blue shark  Not fatal attack
# 21          Undetermined shark  Not fatal attack
# 22                 White shark  Not fatal attack
# 23             Nurse shark, 4'  Not fatal attack
# 24          Undetermined shark  Not fatal attack
# 25          Undetermined shark  Not fatal attack
# 26          Undetermined shark  Not fatal attack
# 27              Bull shark, 6'  Not fatal attack
# 28              reef shark, 1m  Not fatal attack
# 29            Tiger shark, 10'  Not fatal attack
# 30          Undetermined shark  Not fatal attack
# 31          Undetermined shark  Not fatal attack
# 32          Undetermined shark  Not fatal attack
# 33             Lemon shark, 9'  Not fatal attack
# 34                 Angel shark  Not fatal attack
# 35                 White shark  Not fatal attack
# 36               dogfish shark  Not fatal attack
# 37                 White shark  Not fatal attack
# 38          Undetermined shark  Not fatal attack
# 39           Tawny nurse shark  Not fatal attack
# 40              3' to 4' shark  Not fatal attack
# 41          Undetermined shark  Not fatal attack
# 42  Caribbean reef shark, 4.5'  Not fatal attack
# 43                 White shark  Not fatal attack
# 44              3' to 5' shark  Not fatal attack
# 45          Undetermined shark  Not fatal attack
# 46              3' to 4' shark  Not fatal attack
# 47                    5' shark  Not fatal attack
# 48              3' to 4' shark  Not fatal attack
# 49                    3' shark  Not fatal attack

# %% [markdown]
# ## RESOLVIENDO LA HIPOTESIS :

# %%
hipotesis1 = final_data[(final_data["Sex"]== "Male") | (final_data["Sex"]== "Female")]
hipotesis1.head(50)
# Out:
#                                         Name     Sex          Age        Day  \
# 0                               Unknown name    Male           16  September
# 1                             Chucky Luciano    Male           36  September
# 2                               Unknown name    Male           43  September
# 3                            Rory Angiolella    Male  Unknown age  September
# 4                               Unknown name    Male  Unknown age  September
# 6                               Unknown name    Male          60s  September
# 7                               Unknown name  Female           51  September
# 8                               David Jewell    Male           50  September
# 9                             Rylie Williams  Female           12  September
# 10                             Fraser Penman    Male  Unknown age  September
# 11                              Austin Moore    Male            9  September
# 12                           Tyler McQuillen    Male           22  September
# 13                              Sam Cumiskey    Male           25     August
# 14                              Unknown name    Male           37     August
# 15                          Laurent Chardard    Male           20     August
# 16                            David Cassetty    Male           49     August
# 17                              Johnny Stoch    Male           15     August
# 18                             Connor Baxter    Male           21     August
# 19                               Nolan Tyler    Male           22     August
# 20                              Unknown name    Male           40       July
# 21                              Justus Franz    Male           72       July
# 22                               Ian Watkins    Male  Unknown age       July
# 23                               Warren Sapp    Male           43       July
# 24                   Curran See & Harry Lake    Male           18       July
# 25                              Unknown name    Male           29       July
# 26                         Zebulon Critchlow    Male           36       July
# 27                            Steve Cutbirth    Male  Unknown age       July
# 28                           Scott van Burck    Male           31       July
# 30                              Unknown name  Female            9       July
# 31                              Unknown name  Female           11       July
# 32                              Unknown name    Male  Unknown age       July
# 33                         Michael Dornellas    Male  Unknown age       July
# 34                              Unknown name  Female           10       July
# 35                                Mark Davis    Male  Unknown age       July
# 36                             Roger Brissom    Male           59       July
# 37  24' boat Shark Tagger Occupant Keith Poe    Male  Unknown age       July
# 38                              Unknown name  Female           42       July
# 39                             Nathan Oliver    Male           34       July
# 40                              Unknown name    Male           35       June
# 41                              Unknown name    Male           11       June
# 42                              Arturo Velez    Male           59       June
# 43                              Unknown name    Male           43       June
# 44                               Jeff Schott    Male           42       June
# 45                              Unknown name    Male  Unknown age       June
# 46                              Unknown name    Male  Unknown age       June
# 47                                 Brad Vale    Male           19       June
# 48                        Marin Alice Melton  Female            6       June
# 49                              Dillon Bowen    Male           19       June
# 50                              Jack O'Neill    Male           27       June
# 51                              Unknown name    Male           64       June
#
#           Country               Activity  \
# 0             USA                Surfing
# 1             USA                Surfing
# 2             USA                Surfing
# 3       AUSTRALIA                Surfing
# 4       AUSTRALIA                Surfing
# 6             USA                 Wading
# 7             USA               Swimming
# 8   NEW CALEDONIA           Kite surfing
# 9             USA        Boogie boarding
# 10      AUSTRALIA                Surfing
# 11            USA          Body boarding
# 12            USA           Spearfishing
# 13            USA                Surfing
# 14            USA                Surfing
# 15        REUNION                Surfing
# 16            USA                 Wading
# 17        BAHAMAS             Snorkeling
# 18            USA      SUP Foil boarding
# 19            USA                Surfing
# 20          SPAIN               Swimming
# 21          CHINA               Swimming
# 22      AUSTRALIA               Kayaking
# 23            USA             Lobstering
# 24      AUSTRALIA                Surfing
# 25          JAPAN                Surfing
# 26      AUSTRALIA                Surfing
# 27        BAHAMAS           Spearfishing
# 28      AUSTRALIA                Fishing
# 30            USA                Surfing
# 31            USA  Undetermined activity
# 32            USA               Swimming
# 33        BAHAMAS           Scuba Diving
# 34          SPAIN                 Wading
# 35            USA      Fishing for squid
# 36            USA                Fishing
# 37            USA     Fishing for sharks
# 38            USA               Swimming
# 39      AUSTRALIA                Fishing
# 40            USA  Undetermined activity
# 41            USA                Surfing
# 42       COLUMBIA           Scuba Diving
# 43   SOUTH AFRICA           Spearfishing
# 44            USA               Floating
# 45            USA                 Wading
# 46            USA                Surfing
# 47      AUSTRALIA           Spearfishing
# 48            USA       Floating in tube
# 49            USA               Standing
# 50            USA                Surfing
# 51            USA               Swimming
#
#                                            Shark info      Fatal attack
# 0                                  Undetermined shark  Not fatal attack
# 1                                  Undetermined shark  Not fatal attack
# 2                                  Undetermined shark  Not fatal attack
# 3                                  Undetermined shark  Not fatal attack
# 4                                           2 m shark  Not fatal attack
# 6                                      3' to 4' shark  Not fatal attack
# 7                                    Tiger shark, 10?  Not fatal attack
# 8                                  Undetermined shark      Fatal attack
# 9                                  Undetermined shark  Not fatal attack
# 10                                 Undetermined shark  Not fatal attack
# 11                                 Undetermined shark  Not fatal attack
# 12                                        White shark  Not fatal attack
# 13                                     Bull shark, 6'  Not fatal attack
# 14                                 Undetermined shark  Not fatal attack
# 15                                  Bull shark, 3.5 m  Not fatal attack
# 16                                 Undetermined shark  Not fatal attack
# 17                                 Undetermined shark  Not fatal attack
# 18                                   Tiger shark, 10'  Not fatal attack
# 19                                     Blacktip shark  Not fatal attack
# 20                                         Blue shark  Not fatal attack
# 21                                 Undetermined shark  Not fatal attack
# 22                                        White shark  Not fatal attack
# 23                                    Nurse shark, 4'  Not fatal attack
# 24                                 Undetermined shark  Not fatal attack
# 25                                 Undetermined shark  Not fatal attack
# 26                                 Undetermined shark  Not fatal attack
# 27                                     Bull shark, 6'  Not fatal attack
# 28                                     reef shark, 1m  Not fatal attack
# 30                                 Undetermined shark  Not fatal attack
# 31                                 Undetermined shark  Not fatal attack
# 32                                 Undetermined shark  Not fatal attack
# 33                                    Lemon shark, 9'  Not fatal attack
# 34                                        Angel shark  Not fatal attack
# 35                                        White shark  Not fatal attack
# 36                                      dogfish shark  Not fatal attack
# 37                                        White shark  Not fatal attack
# 38                                 Undetermined shark  Not fatal attack
# 39                                  Tawny nurse shark  Not fatal attack
# 40                                     3' to 4' shark  Not fatal attack
# 41                                 Undetermined shark  Not fatal attack
# 42                         Caribbean reef shark, 4.5'  Not fatal attack
# 43                                        White shark  Not fatal attack
# 44                                     3' to 5' shark  Not fatal attack
# 45                                 Undetermined shark  Not fatal attack
# 46                                     3' to 4' shark  Not fatal attack
# 47                                           5' shark  Not fatal attack
# 48                                     3' to 4' shark  Not fatal attack
# 49                                           3' shark  Not fatal attack
# 50  Said to involve an 8' shark but more likely da...  Not fatal attack
# 51                                 Undetermined shark  Not fatal attack
